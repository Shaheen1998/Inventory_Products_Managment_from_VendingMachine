# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir datasets
# %cd datasets
# !gdown --id 1--cxFrvML_B0BCypBrfgA3DNGX8cFnQe   #dataset.zip
# !gdown --id 11WBFGGAHAvzgynh6BO2zPrKtB-b1pX0G   #model file
# Out:
# /content/datasets
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1--cxFrvML_B0BCypBrfgA3DNGX8cFnQe
# From (redirected): https://drive.google.com/uc?id=1--cxFrvML_B0BCypBrfgA3DNGX8cFnQe&confirm=t&uuid=1ab3d4e3-7090-4cfd-a816-3435dc620dce
# To: /content/datasets/vending_machine.zip
# 100% 34.0M/34.0M [00:01<00:00, 20.3MB/s]

# %%
# !unzip vending_machine.zip
# %cd ..
# Out:
# Archive:  vending_machine.zip
#    creating: images/
#    creating: images/train/
#   inflating: images/train/10_2024.04.02-09.08.24.mov_frame1005.jpg
#   inflating: images/train/10_2024.04.02-09.08.24.mov_frame1035.jpg
#   inflating: images/train/10_2024.04.02-09.08.24.mov_frame1050.jpg
#   inflating: images/train/10_2024.04.02-09.08.24.mov_frame1095.jpg
#   inflating: images/train/10_2024.04.02-09.08.24.mov_frame1110.jpg
#   inflating: images/train/10_2024.04.02-09.08.24.mov_frame1215.jpg
#   inflating: images/train/10_2024.04.02-09.08.24.mov_frame1245.jpg
#   inflating: images/train/10_2024.04.02-09.08.24.mov_frame150.jpg
#   inflating: images/train/10_2024.04.02-09.08.24.mov_frame165.jpg
#   inflating: images/train/10_2024.04.02-09.08.24.mov_frame180.jpg
#   inflating: images/train/10_2024.04.02-09.08.24.mov_frame195.jpg
#   inflating: images/train/10_2024.04.02-09.08.24.mov_frame210.jpg
#   inflating: images/train/10_2024.04.02-09.08.24.mov_frame225.jpg
# ...

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.9/78.2 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=datasets/data.yaml epochs=130 cache=True plots=True  #train

# !yolo 'task=detect' 'mode=train' 'resume=True' 'model=/content/runs/detect/train/weights/best.pt' 'data=data.yaml'

# !pwd
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo 'task=detect' 'mode=predict' 'source=/content/datasets/holes/images/test' 'model=/content/datasets/yolov8m_62.pt' 'data=/content/datasets/holes/data.yaml'

# %%
# !yolo detect predict model=/content/runs/detect/train2/weights/best.pt source=/content/1_2024.03.04-22.19.55.mov save=True
# Out:
# 2024-05-11 12:19:31.999411: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-11 12:19:31.999462: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-11 12:19:32.000761: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-11 12:19:33.192991: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# ...
